# %%
import matplotlib.pyplot as plt
import numpy as np
###gateset1
gateset=1
if gateset==0 :
    p =    [0.85118  , 0.90825  , 0.90349   , 0.90582 ,  0.93724  , 0.92943]
    p_std =[0.0077795, 0.0010086, 0.00010649, 0.0022572, 0.0013993, 0.00021653]
else:
    p =    [0.8432  , 0.90495  , 0.9031  ,  0.89945 , 0.93683 , 0.92847]
    p_std =[0.0058145, 0.0021489, 0.00012491, 0.0028867, 0.0016723, 0.00026216]
x=['depo', 'deph']
plt.plot(['depo_err', 'deph_err'], [ (0.9-p[0])/0.9 , (0.92-p[3])/0.92  ], marker ="o", markersize=15, color='r' ,label='RB', linestyle='')
plt.plot(['depo_err', 'deph_err'], [ (0.9-p[1])/0.9 ,  (0.92-p[4])/0.92 ], marker ="+", markersize=15, color='g' ,label='PRB', linestyle='')
plt.plot(['depo_err', 'deph_err'], [ (0.9-p[2])/0.9 ,  (0.92-p[5])/0.92 ], marker ="v", markersize=15, color='b' ,label='PRB_fliter', linestyle='')
plt.legend(loc = 9)
plt.hlines(y=0,xmin='depo_err',xmax='deph_err')
plt.show()

# %%
x=['depo', 'deph']
plt.plot(['depo_std', 'deph_std'], [ p_std[0] , p_std[3]  ], marker ="o", markersize=15, color='r' ,label='RB', linestyle='')
plt.plot(['depo_std', 'deph_std'], [ p_std[1] , p_std[4]  ], marker ="+", markersize=15, color='g' ,label='PRB', linestyle='')
plt.plot(['depo_std', 'deph_std'], [ p_std[2] , p_std[5]  ], marker ="v", markersize=15, color='b' ,label='PRB_fliter', linestyle='')
plt.legend(loc = 9)
plt.hlines(y=0,xmin='depo_std',xmax='deph_std')
plt.show()
