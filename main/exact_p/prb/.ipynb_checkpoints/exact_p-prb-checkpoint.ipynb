# %%
#noiseless
from pyquil.simulation.matrices import I, X, Y, Z
import numpy as np
from forest.benchmarking.operator_tools import kraus2pauli_liouville
from print_large import _print_big_matrix
import pickle
from tqdm import tqdm
import multiprocessing as mp
import random
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from functools import reduce
#gateset1 [1, 9601, 8129, 3103, 2296, 0, 0, 9285, 8118, 2974, 3058, 0, 0, 10523, 9788]
#gateset2 [16192, 11846, 15055, 13880, 10476, 10481]


#### 2-qubit pauli basis
pauli_basis=[np.asarray(np.kron(i,j)) for i in [I, X, Y, Z] for j in [I, X, Y, Z]]
#### 2-qubit |0> and |1>
e_state=np.kron(np.asarray([[0,0],[0,1]]),np.asarray([[0,0],[0,1]]))
g_state=np.kron(np.asarray([[1,0],[0,0]]),np.asarray([[1,0],[0,0]]))
####Density matrix to PTM
def densityop_01_2_pauli(density_op):
    A=np.asarray([np.trace(density_op@i_den) for i_den in pauli_basis]).reshape(density_op.size,1)
    return A
def densityop_pauli_2_01(density_op):
    A_den=np.asarray([density_op[i_den]*pauli_basis[i_den] for i_den in range(16)])
    B_den=np.zeros((4,4))
    for i_den in A_den:
        B_den=B_den+i_den
    return B_den/4
def dephaseing_PTM(p):
    A=[np.kron(i_deph,j_deph) for i_deph in [I,Z] for j_deph in [I,Z]]
    for i_deph in [0]:
        A[i_deph] = A[i_deph]*np.sqrt(p+(1-p)/4)
    for i_deph in [1,2,3]:
        A[i_deph] = A[i_deph]*np.sqrt((1-p)/4)
#########kraus to PTM 
    return kraus2pauli_liouville(A)
def depolarizing_PTM(p):
    p=1-p
    A=[np.kron(i_depo,j_depo) for i_depo in [I,X,Y,Z] for j_depo in [I,X,Y,Z]]
    A[0] = A[0]*np.sqrt(1-15*p/16)
    for i_depo in range(1,len(A)):
        A[i_depo]=A[i_depo]*np.sqrt(p/16)
#########kraus to PTM        
    return kraus2pauli_liouville(A)
def sequence_to_probability(_rb_seq):
####initial state    
    _state=densityop_01_2_pauli(g_state)
####depo or deph=  noise channel @ Cliff @ state
    if noise_channel==0:
        noise=depolarizing_PTM(noise_strength)
        _state=reduce(lambda x,y: y@noise@x, [P_PTM[_i] for _i in _rb_seq])@_state
    elif noise_channel==1:
        noise=dephaseing_PTM(noise_strength)
        _state=reduce(lambda x,y: y@noise@x, [P_PTM[_i] for _i in _rb_seq])@_state
#### inverse no noise        
####get [00] prob
    return np.real(densityop_pauli_2_01(_state)[0][0])

# %%
if __name__ == '__main__':

####### input
    print('prb')
    gateset=int(input('gateset'))
    max_seq= int(input('max seq \n'))
    noise_channel= int(input('depolarizing (0) or dephasing (1) \n'))
    noise_strength= float(input('noisy(0)-----(1)noiseless\n'))
    data={}
###primitive gate PTM
    with open('P_PTM_gateset'+str(gateset)+'.pkl', 'rb') as f:
        P_PTM = pickle.load(f)
###rb_seq_deompose
    with open('rb_2_prb_gateset'+str(gateset)+'.pkl', 'rb') as f:
        rb_seq_decompose = pickle.load(f)
####### rb gate number i    
    for i in tqdm(list(filter(lambda x: x<max_seq, list(rb_seq_decompose.keys()))),ascii=True,desc="sequence_length",dynamic_ncols=True):
####### rb sequence into probablility
        pool = mp.Pool()
        repeat_probability = pool.map(sequence_to_probability,rb_seq_decompose[i])
        pool.close()
        pool.join()
        data[i]=repeat_probability
    #df = pd.DataFrame(data)
    #df.to_csv('data.csv')
    with open('prbdata_gateset'+str(gateset)+'.pkl', 'wb') as f:
        pickle.dump(data, f)
#    print('real_p=',(np.real(sum(np.diagonal(depolarizing_PTM(0.9)))-1))/15)
# Out:
# prb
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-f30ee011806f> in <module>
#       3 ####### input
#       4     print('prb')
# ----> 5     gateset=int(input('gateset'))
#       6     max_seq= int(input('max seq \n'))
#       7     noise_channel= int(input('depolarizing (0) or dephasing (1) \n'))
#
# ~/anaconda3/envs/prb/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/anaconda3/envs/prb/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from functools import reduce
with open('prbdata_gateset'+str(gateset)+'.pkl', 'rb') as f:
    data = pickle.load(f)
sns.violinplot(data=[data[i] for i in list(data.keys())])
plt.axhline(y=0.25)
plt.show()

##########################################################################
### Fit
import os
import numpy as np
import fnmatch
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

#fitting function
def fit_p(x,p):
    return 0.75*p**x+0.25
##############
def plot(sequence_length,p_mean,p_std):
#####fit
    sequence_length=[i for i in sequence_length]
    mean,cov = curve_fit(fit_p,sequence_length,p_mean,p0=[0.5],bounds=(0,1))
    ##,sigma=p_std, absolute_sigma = True,
    print('fitting p = ','%.5g' % mean[0])
    print('fitting perr = ','%.5g' % np.sqrt(np.diag(cov)))
########plot
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(sequence_length,p_mean,'.',color='r',markerfacecolor='none',markersize=9,label='gate_set1_PRB')
    ax.plot(sequence_length,fit_p(sequence_length, mean),'-',color='r',label='gate_set1_fit')

    #ax.set_xscale('log')
    ax.legend(loc='best')
    plt.xscale('log')
    plt.title('PRB')
#    plt.savefig('PRB'+str(gateset)+'.png')
plot(list(data.keys()),[np.mean(data[i]) for i in data],[np.std(data[i]) for i in data])
# Out:
# fitting p =  0.83787
# fitting perr =  0.004293

# %%
a=list(data.keys())
b=a[12:]
sns.violinplot(data=[data[i] for i in b])
plt.axhline(y=0.25)
plt.show()

##########################################################################
### Fit

#fitting function
def fit_p(x,p):
    return 0.75*p**x+0.25
##############
def plot(sequence_length,p_mean,p_std):
#####fit
    sequence_length=[i for i in sequence_length]
    mean,cov = curve_fit(fit_p, sequence_length,p_mean,p0=[0.5],bounds=(0,1))
    ##,sigma=p_std, absolute_sigma = True,
    print('fitting p = ','%.5g' % mean[0])
    print('fitting perr = ','%.5g' % np.sqrt(np.diag(cov)))
########plot
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(sequence_length,p_mean,'.',color='r',markerfacecolor='none',markersize=9,label='gate_set1_PRB')
    ax.plot(sequence_length,fit_p(sequence_length, mean),'-',color='r',label='gate_set1_fit')

    #ax.set_xscale('log')
    ax.legend(loc='best')
    plt.xscale('log')
    plt.title('PRB')
    #plt.savefig('PRB'+str(gateset)+'.png')
plot(b,[np.mean(data[i]) for i in b],[np.std(data[i]) for i in b])
# Out:
# fitting p =  0.92847
# fitting perr =  0.00026216

# %%
#noiseless interleaved iprb
from pyquil.simulation.matrices import I, X, Y, Z
import numpy as np
from forest.benchmarking.operator_tools import kraus2pauli_liouville
from print_large import _print_big_matrix
import pickle
from tqdm import tqdm
import multiprocessing as mp
import random
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from functools import reduce
#gateset1 [1, 9601, 8129, 3103, 2296, 0, 0, 9285, 8118, 2974, 3058, 0, 0, 10523, 9788]
#gateset2 [16192, 11846, 15055, 13880, 10476, 10481]


#### 2-qubit pauli basis
pauli_basis=[np.asarray(np.kron(i,j)) for i in [I, X, Y, Z] for j in [I, X, Y, Z]]
#### 2-qubit |0> and |1>
e_state=np.kron(np.asarray([[0,0],[0,1]]),np.asarray([[0,0],[0,1]]))
g_state=np.kron(np.asarray([[1,0],[0,0]]),np.asarray([[1,0],[0,0]]))
####Density matrix to PTM
def densityop_01_2_pauli(density_op):
    A=np.asarray([np.trace(density_op@i_den) for i_den in pauli_basis]).reshape(density_op.size,1)
    return A
def densityop_pauli_2_01(density_op):
    A_den=np.asarray([density_op[i_den]*pauli_basis[i_den] for i_den in range(16)])
    B_den=np.zeros((4,4))
    for i_den in A_den:
        B_den=B_den+i_den
    return B_den/4
def dephaseing_PTM(p):
    A=[np.kron(i_deph,j_deph) for i_deph in [I,Z] for j_deph in [I,Z]]
    for i_deph in [0]:
        A[i_deph] = A[i_deph]*np.sqrt(p+(1-p)/4)
    for i_deph in [1,2,3]:
        A[i_deph] = A[i_deph]*np.sqrt((1-p)/4)
#########kraus to PTM 
    return kraus2pauli_liouville(A)
def depolarizing_PTM(p):
    p=1-p
    A=[np.kron(i_depo,j_depo) for i_depo in [I,X,Y,Z] for j_depo in [I,X,Y,Z]]
    A[0] = A[0]*np.sqrt(1-15*p/16)
    for i_depo in range(1,len(A)):
        A[i_depo]=A[i_depo]*np.sqrt(p/16)
#########kraus to PTM        
    return kraus2pauli_liouville(A)
def sequence_to_probability(_rb_seq):
####initial state    
    _state=densityop_01_2_pauli(g_state)
####depo or deph=  noise channel @ Cliff @ state
    if noise_channel==0:
        noise=depolarizing_PTM(noise_strength)
        _state=reduce(lambda x,y: y@noise@x, [P_PTM[_i] for _i in _rb_seq])@_state
    elif noise_channel==1:
        noise=dephaseing_PTM(noise_strength)
        _state=reduce(lambda x,y: y@noise@x, [P_PTM[_i] for _i in _rb_seq])@_state
#### inverse no noise        
####get [00] prob
    return np.real(densityop_pauli_2_01(_state)[0][0])
# Out:
# /home/r07222078/anaconda3/envs/prb/lib/python3.9/site-packages/pyquil/gate_matrices.py:21: FutureWarning: The code in pyquil.gate_matrices has been moved to pyquil.simulation.matrices, please update your import statements.
#   warnings.warn(

# %%
if __name__ == '__main__':

####### input
    print('iprb')
    gateset=int(input('gateset'))
    interleaved_gate=int(input('interleaved_gate'))
    
    max_seq= int(input('max seq \n'))
    noise_channel= int(input('depolarizing (0) or dephasing (1) \n'))
    noise_strength= float(input('noisy(0)-----(1)noiseless\n'))
    i_data={}
###primitive gate PTM
    with open('P_PTM_gateset'+str(gateset)+'.pkl', 'rb') as f:
        P_PTM = pickle.load(f)
###rb_seq_deompose
    with open(str(interleaved_gate)+'iprb_seq_gateset'+str(gateset)+'.pkl', 'rb') as f:
        rb_seq_decompose = pickle.load(f)
####### rb gate number i    
    for i in tqdm(list(filter(lambda x: x<max_seq, list(rb_seq_decompose.keys()))),ascii=True,desc="sequence_length",dynamic_ncols=True):
####### rb sequence into probablility
        pool = mp.Pool()
        repeat_probability = pool.map(sequence_to_probability,rb_seq_decompose[i])
        pool.close()
        pool.join()
        i_data[i]=repeat_probability
    #df = pd.DataFrame(data)
    #df.to_csv('data.csv')
    with open(str(interleaved_gate)+'iprbdata_gateset'+str(gateset)+'.pkl', 'wb') as f:
        pickle.dump(i_data, f)
    print('real_p=',(np.real(sum(np.diagonal(dephaseing_PTM(noise_strength)))-1))/15)
# Out:
# iprb
# gateset1
# interleaved_gate227
# max seq
# 100
# depolarizing (0) or dephasing (1)
# 1
# noisy(0)-----(1)noiseless
# 0.9
# sequence_length: 100%|##########| 99/99 [01:51<00:00,  1.13s/it]
# real_p= 0.9200000000000002

# %%
from functools import reduce
with open(str(interleaved_gate)+'iprbdata_gateset'+str(gateset)+'.pkl', 'rb') as f:
    data = pickle.load(f)
sns.violinplot(data=[data[i] for i in list(data.keys())])
plt.axhline(y=0.25)
plt.show()

##########################################################################
### Fit
import os
import numpy as np
import fnmatch
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

#fitting function
def fit_p(x,p):
    return 0.75*p**x+0.25
##############
def plot(sequence_length,p_mean,p_std):
#####fit
    sequence_length=[i for i in sequence_length]
    mean,cov = curve_fit(fit_p,sequence_length,p_mean,p0=[0.5],bounds=(0,1))
    ##,sigma=p_std, absolute_sigma = True,
    print('fitting p = ','%.5g' % mean[0])
    print('fitting perr = ','%.5g' % np.sqrt(np.diag(cov)))
########plot
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(sequence_length,p_mean,'.',color='r',markerfacecolor='none',markersize=9,label='gate_set1_PRB')
    ax.plot(sequence_length,fit_p(sequence_length, mean),'-',color='r',label='gate_set1_fit')

    #ax.set_xscale('log')
    ax.legend(loc='best')
    plt.xscale('log')
    plt.title(str(interleaved_gate)+'iPRB')
#    plt.savefig('PRB'+str(gateset)+'.png')
plot(list(data.keys()),[np.mean(data[i]) for i in data],[np.std(data[i]) for i in data])
# Out:
# fitting p =  0.91051
# fitting perr =  0.0016416

# %%
a=list(data.keys())
b=a[22:]
sns.violinplot(data=[data[i] for i in b])
plt.axhline(y=0.25)
plt.show()

##########################################################################
### Fit

#fitting function
def fit_p(x,p):
    return 0.75*p**x+0.25
##############
def plot(sequence_length,p_mean,p_std):
#####fit
    sequence_length=[i for i in sequence_length]
    mean,cov = curve_fit(fit_p, sequence_length,p_mean,p0=[0.5],bounds=(0,1))
    ##,sigma=p_std, absolute_sigma = True,
    print('fitting p = ','%.5g' % mean[0])
    print('fitting perr = ','%.5g' % np.sqrt(np.diag(cov)))
########plot
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(sequence_length,p_mean,'.',color='r',markerfacecolor='none',markersize=9,label='gate_set1_PRB')
    ax.plot(sequence_length,fit_p(sequence_length, mean),'-',color='r',label='gate_set1_fit')

    #ax.set_xscale('log')
    ax.legend(loc='best')
    plt.xscale('log')
    plt.title('iPRB_filter')
    #plt.savefig('PRB'+str(gateset)+'.png')
plot(b,[np.mean(data[i]) for i in b],[np.std(data[i]) for i in b])
# Out:
# fitting p =  0.81
# fitting perr =  3.3048e-09

# %%
0.91051/0.937
# Out:
# 0.9717289220917823

# %%
 0.97118/0.984
# Out:
# 0.9869715447154472
