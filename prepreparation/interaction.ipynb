# %%
#find inverse
import pickle
import numpy as np
from print_large import _print_big_matrix
from tqdm import tqdm
from multiprocessing import Process, Pool
from tqdm.notebook import trange, tqdm


with open('Cliff_kruas.pkl', 'rb') as f:
    Cliff_kruas = pickle.load(f)

def fun(k):
    if np.allclose(np.absolute(np.trace(l@Cliff_kruas[k])), 4):
        Cliff_inverse_index[(i-1)*11520+j]=k
    else:
        assert k != (len(Cliff_kruas)-1), "no inverse"
    return None

if __name__ == '__main__':
    Cliff_inverse_index = np.zeros(11520*11520)
    for i in tqdm(range(len(Cliff_kruas)-1), desc="outter"):
        for j in tqdm(range(len(Cliff_kruas)-1), desc="inner"):
            l=np.conj(Cliff_kruas[j]@Cliff_kruas[i]).T
            pool = Pool()
            pool.map(fun,[ k for k in range(len(Cliff_kruas)-1)])
            pool.close()
            pool.join()

            #results = [int(_i) for _i in filter(None, results)]
            #assert len(results)==1, 'not one inverse'
            #Cliff_inverse_index += results

            

    with open('Cliff_inverse_index.pkl', 'wb') as f:
        pickle.dump(Cliff_inverse_index.reshape(11520,11520), f)
# Out:
# HBox(children=(IntProgress(value=0, description='outter', max=11518, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='inner', max=11518, style=ProgressStyle(description_width='ini…
# /process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-f68192e9a5f9>", line 14, in fun
#     if np.allclose(np.absolute(np.trace(l@Cliff_kruas[k])), 4):
#   File "<ipython-input-3-f68192e9a5f9>", line 14, in fun
#     if np.allclose(np.absolute(np.trace(l@Cliff_kruas[k])), 4):
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<__array_function__ internals>", line 6, in allclose
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "<ipython-input-3-f68192e9a5f9>", line 14, in fun
#     if np.allclose(np.absolute(np.trace(l@Cliff_kruas[k])), 4):
#   File "<ipython-input-3-f68192e9a5f9>", line 14, in fun
#     if np.allclose(np.absolute(np.trace(l@Cliff_kruas[k])), 4):
#   File "<ipython-input-3-f68192e9a5f9>", line 14, in fun
#     if np.allclose(np.absolute(np.trace(l@Cliff_kruas[k])), 4):
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2171, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 6, in allclose
#   File "<__array_function__ internals>", line 6, in allclose
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "<ipython-input-3-f68192e9a5f9>", line 14, in fun
#     if np.allclose(np.absolute(np.trace(l@Cliff_kruas[k])), 4):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-3-f68192e9a5f9>", line 14, in fun
#     if np.allclose(np.absolute(np.trace(l@Cliff_kruas[k])), 4):
#   File "<__array_function__ internals>", line 6, in isclose
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<__array_function__ internals>", line 6, in allclose
#   File "<__array_function__ internals>", line 6, in allclose
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<__array_function__ internals>", line 6, in allclose
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2272, in isclose
#     return within_tol(x, y, atol, rtol)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2171, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2171, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2171, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<__array_function__ internals>", line 6, in isclose
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2171, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2171, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2258, in within_tol
#     return less_equal(abs(x-y), atol + rtol * abs(y))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2272, in isclose
#     return within_tol(x, y, atol, rtol)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "<__array_function__ internals>", line 6, in isclose
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "<__array_function__ internals>", line 6, in isclose
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 6, in isclose
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "<__array_function__ internals>", line 6, in isclose
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2272, in isclose
#     return within_tol(x, y, atol, rtol)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2258, in within_tol
#     return less_equal(abs(x-y), atol + rtol * abs(y))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2271, in isclose
#     if all(xfin) and all(yfin):
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2271, in isclose
#     if all(xfin) and all(yfin):
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2269, in isclose
#     xfin = isfinite(x)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 6, in all
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2258, in within_tol
#     return less_equal(abs(x-y), atol + rtol * abs(y))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 6, in all
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2277, in all
#     @array_function_dispatch(_all_dispatcher)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2351, in all
#     return _wrapreduction(a, np.logical_and, 'all', axis, None, out, keepdims=keepdims)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 88, in _wrapreduction
#     return reduction(axis=axis, out=out, **passkwargs)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-f68192e9a5f9>", line 14, in fun
#     if np.allclose(np.absolute(np.trace(l@Cliff_kruas[k])), 4):
# KeyboardInterrupt
#   File "/home/gin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<__array_function__ internals>", line 6, in allclose
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2171, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#   File "<ipython-input-3-f68192e9a5f9>", line 14, in fun
#     if np.allclose(np.absolute(np.trace(l@Cliff_kruas[k])), 4):
#   File "<__array_function__ internals>", line 6, in isclose
#   File "<__array_function__ internals>", line 6, in allclose
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2271, in isclose
#     if all(xfin) and all(yfin):
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2171, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#   File "<__array_function__ internals>", line 6, in isclose
#   File "<__array_function__ internals>", line 6, in all
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 2266, in isclose
#     dt = multiarray.result_type(y, 1.)
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2351, in all
#     return _wrapreduction(a, np.logical_and, 'all', axis, None, out, keepdims=keepdims)
#   File "<__array_function__ internals>", line 4, in result_type
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 88, in _wrapreduction
#     return reduction(axis=axis, out=out, **passkwargs)
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/multiarray.py", line 635, in result_type
#     @array_function_from_c_func_and_dispatcher(_multiarray_umath.result_type)
#   File "/home/gin/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py", line 48, in _all
#     return umr_all(a, axis, dtype, out, keepdims)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f68192e9a5f9> in <module>
#      24             l=np.conj(Cliff_kruas[j]@Cliff_kruas[i]).T
#      25             pool = Pool()
# ---> 26             pool.map(fun,[ k for k in range(len(Cliff_kruas)-1)])
#      27             pool.close()
#      28             pool.join()
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
